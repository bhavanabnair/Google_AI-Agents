# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}")
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The integration of quantum computing with artificial intelligence, often termed "Quantum AI," is poised to revolutionize numerous industries by overcoming the limitations of classical computing. This synergy promises to accelerate AI development, enhance its capabilities, and unlock solutions to problems currently considered intractable.
#
# Key advancements and implications include:
#
# *   **Accelerated AI Development & Enhanced Capabilities:** Quantum computers, with their ability to process vast information and explore multiple solutions simultaneously using qubits, can drastically speed up AI training, complex optimization tasks, and simulations. This leads to supercharged AI performance and more efficient data processing, enabling AI to tackle problems previously considered intractable.
# *   **Industry-Wide Transformation:** Quantum AI is poised to revolutionize sectors like healthcare (drug discovery, personalized medicine), finance (risk assessment), manufacturing and logistics (supply chain optimization), transportation (traffic management), cybersecurity (threat detection and quantum-resistant encryption), and climate modeling through enhanced AI capabilities.
# *   **Overcoming Limitations & Sustainability:** Quantum computing can break through current hardware bottlenecks in AI, allowing for the development of more sophisticated models. It also offers a more energy-efficient approach to AI, potentially reducing consumption compared to classical models.
# *   **Symbiotic Advancement:** The relationship is bidirectional, with AI also playing a crucial role in improving quantum systems by enhancing their reliability, reducing errors, and optimizing performance.

# %% [markdown]
# You've just built your first multi-agent system! You used a single "coordinator" agent to manage the workflow, which is a powerful and flexible pattern.
#
# ‼️ However, **relying on an LLM's instructions to control the order can sometimes be unpredictable.** Next, we'll explore a different pattern that gives you guaranteed, step-by-step execution.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %% [markdown]
# Then we bring the agents together under a sequential agent, which runs the agents in the order that they are listed:

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %% [markdown]
# Let's run the agent and give it a topic to write a blog post about:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Okay, I am OutlineAgent. Here is a blog outline about the benefits of multi-agent systems for software developers:
#
# ## Headline: Unlock Superpowers for Your Code: The Multi-Agent Systems Advantage for Developers
#
# ### Introduction Hook:
#
# *   Tired of monolithic codebases that are a nightmare to maintain and scale?
# *   Imagine a world where complex problems are tackled by a team of specialized, intelligent software "agents," each handling its own piece of the puzzle.
# *   This isn't science fiction; it's the reality of Multi-Agent Systems (MAS), and it's about to revolutionize how you build software.
#
# ### Section 1: Enhanced Modularity and Maintainability
#
# *   **Break Down Complexity:** MAS allows you to decompose large, intricate problems into smaller, manageable, and independent agents. Each agent can focus on a specific task or domain, leading to cleaner, more focused code.
# *   **Easier Updates and Debugging:** Need to update a specific feature? With MAS, you can modify or replace individual agents without drastically affecting the rest of the system. Debugging becomes more targeted as you can isolate issues within specific agents.
# *   **Improved Team Collaboration:** Different teams or developers can own and work on distinct agents concurrently, fostering parallel development and reducing merge conflicts in large projects.
#
# ### Section 2: Increased Robustness and Resilience
#
# *   **Fault Tolerance:** If one agent fails, the system can often continue to function, perhaps with degraded performance, thanks to the remaining agents. This contrasts sharply with monolithic systems where a single point of failure can bring everything down.
# *   **Adaptability to Changing Environments:** Agents can be designed to monitor their environment and adapt their behavior, or even communicate with other agents to collectively overcome unexpected challenges or shifts.
# *   **Graceful Degradation:** Instead of a complete system crash, MAS can allow for graceful degradation of services when certain components are unavailable, providing a more reliable user experience.
#
# ### Section 3: Scalability and Performance Gains
#
# *   **Parallel Processing:** Agents can operate concurrently, performing tasks in parallel. This inherent parallelism makes MAS ideal for distributed computing and handling high loads.
# *   **Dynamic Resource Allocation:** Agents can be scaled up or down independently based on demand, allowing for efficient resource utilization and cost optimization in cloud environments.
# *   **Specialized Optimization:** Each agent can be optimized for its specific task, potentially leading to better overall performance than a single, general-purpose component trying to do everything.
#
# ### Section 4: Novel Problem-Solving Capabilities
#
# *   **Emergent Behavior:** Complex system-level behaviors can emerge from the interactions of simple, individually programmed agents, leading to innovative solutions that might be difficult to explicitly design.
# *   **Decentralized Decision-Making:** MAS excels in scenarios where centralized control is impractical or undesirable. Agents can make local decisions that contribute to a global objective.
# *   **Simulation and Modeling:** MAS provides a powerful framework for simulating complex real-world systems, from traffic flow to economic markets, allowing developers to test and refine solutions in a controlled environment.
#
# ### Concluding Thought:
#
# *   The era of the isolated developer is fading. By embracing Multi-Agent Systems, you're not just building software; you're orchestrating an intelligent ecosystem of collaborating components. Get ready to build more resilient, scalable, and innovative applications than ever before – your code (and your users) will thank you for it.
# WriterAgent > ## Unlock Superpowers for Your Code: The Multi-Agent Systems Advantage for Developers
#
# Are you weary of wrestling with monolithic codebases that feel impossible to scale or maintain? Picture this: instead of a single, sprawling behemoth, your software is a team of specialized, intelligent "agents," each a master of its own domain, working in harmony to solve complex problems. This isn't a scene from a futuristic movie; it's the burgeoning reality of Multi-Agent Systems (MAS), and it's poised to transform how you develop software.
#
# MAS fundamentally shifts your approach by breaking down daunting challenges into smaller, manageable, and independent agents. This enhanced modularity means cleaner code, easier updates, and more targeted debugging. Imagine a scenario where modifying one feature doesn't send ripples of unintended consequences throughout your entire system. Furthermore, different development teams can work on distinct agents concurrently, accelerating development and minimizing merge conflicts in large-scale projects.
#
# Beyond maintainability, MAS imbues your software with impressive robustness. If one agent falters, the rest of the system can often continue operating, providing a level of fault tolerance that monolithic systems simply can't match. Agents can also be designed to adapt to changing environments, communicating and collaborating to overcome unforeseen obstacles, leading to graceful degradation rather than catastrophic failure.
#
# The benefits extend to performance and scalability. MAS naturally lends itself to parallel processing, allowing agents to work concurrently and significantly boosting efficiency, especially in distributed computing environments. Resources can be dynamically allocated and agents scaled independently, optimizing performance and cost in the cloud.
#
# Finally, MAS unlocks novel problem-solving capabilities. Complex, emergent behaviors can arise from simple agent interactions, leading to innovative solutions. Decentralized decision-making empowers systems where central control is impractical, and MAS provides a powerful framework for simulating and modeling intricate real-world scenarios. Embracing MAS means orchestrating an intelligent ecosystem, building more resilient, scalable, and groundbreaking applications.
# EditorAgent > ## Unlock Superpowers for Your Code: The Multi-Agent Systems Advantage for Developers
#
# Are you tired of wrestling with monolithic codebases that feel impossible to scale or maintain? Imagine this: instead of a single, sprawling behemoth, your software is a team of specialized, intelligent "agents," each a master of its own domain, working in harmony to solve complex problems. This isn't a scene from a futuristic movie; it's the burgeoning reality of Multi-Agent Systems (MAS), and it's poised to transform how you develop software.
#
# MAS fundamentally shifts your approach by breaking down daunting challenges into smaller, manageable, and independent agents. This enhanced modularity translates to cleaner code, easier updates, and more targeted debugging. Picture a scenario where modifying one feature doesn't send ripples of unintended consequences throughout your entire system. Furthermore, different development teams can work on distinct agents concurrently, accelerating development and minimizing merge conflicts in large-scale projects.
#
# Beyond maintainability, MAS imbues your software with impressive robustness. If one agent falters, the rest of the system can often continue operating, providing a level of fault tolerance that monolithic systems simply cannot match. Agents can also be designed to adapt to changing environments, communicating and collaborating to overcome unforeseen obstacles, leading to graceful degradation rather than catastrophic failure.
#
# The benefits extend to performance and scalability. MAS naturally lends itself to parallel processing, allowing agents to work concurrently and significantly boosting efficiency, especially in distributed computing environments. Resources can be dynamically allocated and agents scaled independently, optimizing performance and cost in the cloud.
#
# Finally, MAS unlocks novel problem-solving capabilities. Complex, emergent behaviors can arise from simple agent interactions, leading to innovative solutions. Decentralized decision-making empowers systems where central control is impractical, and MAS provides a powerful framework for simulating and modeling intricate real-world scenarios. Embracing MAS means orchestrating an intelligent ecosystem, building more resilient, scalable, and groundbreaking applications.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > Here's a concise executive briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** Advances include AI-driven early detection of sepsis and other critical conditions, with widespread clinical adoption expected within the next few years. Another significant development is teplizumab, a drug that delays Type 1 diabetes onset, already approved and in use. Furthermore, the development of RSV vaccines offers protection for vulnerable populations, with approvals and recommendations rolling out now.
#
# **Tech:** Generative AI continues its rapid advancement, with applications expanding across industries for content creation and task automation. Quantum computing is making strides in hardware and software, though practical, widespread business applications are still estimated to be several years to a decade away. The Internet of Things (IoT) is further integrating into various sectors, enhancing efficiency and data collection, with market projections showing significant growth through 2030.
#
# **Finance:** AI and machine learning are revolutionizing risk assessment, personalization, and fraud detection, with widespread integration already occurring. Blockchain and decentralized finance (DeFi) continue to evolve, with new use cases emerging in supply chain management and security. The development of Central Bank Digital Currencies (CBDCs) and tokenization is also a growing trend, with significant implications for cross-border payments and financial stability expected in the coming years.
# FinanceResearcher > Here's your daily executive briefing:
#
# **Tech Trends:**
# *   **Generative AI Expansion:** AI, particularly generative AI, is rapidly evolving, moving beyond basic applications to more complex and scaled uses. This includes agentic AI, AI governance platforms, and applications in system testing and synthetic data generation. Market implications include increased automation, enhanced decision-making, and potential for personalized user experiences. The future outlook points to AI becoming integral to business strategy, though challenges in governance and ethical deployment remain.
# *   **Application-Specific Semiconductors:** Driven by the immense computational demands of AI, specialized semiconductors are gaining traction. These are crucial for efficient AI training and inference, managing power consumption, and reducing costs. This trend will shape hardware innovation and the competitive landscape for chip manufacturers.
#
# **Health Trends:**
# *   **Rising Healthcare Costs and Utilization:** Medical trends are projected to remain high, driven by increased utilization due to chronic conditions, an aging population, and reliance on advanced, costly treatments. Healthcare staff shortages also contribute by shifting care to more expensive settings. The market implication is a significant pressure on employers and health plans to balance cost control with benefit optimization.
# *   **Focus on Prevention and Lifestyle Interventions:** There's a growing emphasis on preventive care and lifestyle interventions, such as "Food is Medicine" initiatives. These programs aim to integrate nutrition and lifestyle changes into healthcare to manage chronic diseases and improve health equity, potentially offering cost-effective solutions.
#
# **Finance Trends:**
# *   **Finance Leaders as Strategy Drivers:** Finance executives are increasingly taking on strategic roles, moving beyond traditional financial management. They are leveraging advanced AI and cloud technologies to drive innovation, optimize costs, and orchestrate enterprise-wide growth. Market implications include a demand for new skill sets and a more integrated approach to financial planning and strategy.
# *   **Growth in Private Credit and Asset-Backed Finance:** Demand for investment-grade private credit is high as institutional investors seek yield. Similarly, asset-backed finance is gaining traction due to its diversification and predictable cash flows. This indicates a shift in capital markets, with non-traditional lenders and financial instruments playing a larger role.
# TechResearcher > Here is your daily executive briefing:
#
# **Key AI/ML Trends for 2025:**
#
# 1.  **Agentic AI and Autonomous Systems:** AI agents capable of independent task completion are emerging, moving beyond simple assistance to proactive decision-making. Major companies like Google, Microsoft, and OpenAI are investing heavily in this area. The impact will be significant automation across various business functions, potentially revolutionizing workflows.
# 2.  **Specialized and Smaller AI Models (SLMs):** There's a shift from massive, general-purpose models to smaller, domain-specific models (SLMs) trained on enterprise data. This trend, involving companies like Google and IBM, promises greater accuracy, speed, and cost-effectiveness for specific industry needs.
# 3.  **Generative AI Expansion:** Generative AI is moving beyond content creation (text, images) to complex applications like drug discovery, materials science, and advanced multimedia generation. Google, OpenAI, and Microsoft are leading this charge, with the potential for enormous impact on scientific research and industrial innovation.
#
# **Major Companies Involved:**
#
# *   **AI/ML:** Google (Alphabet), Microsoft, OpenAI, IBM, Meta, Nvidia, Anthropic, Apple.
# *   **Tech Briefings:** Daily Executive Briefs, Emmre, Xelvia Global, Advisory Board.
# *   **Health Briefings:** Advisory Board, KFF Health News, International Federation of Health Plans (iFHP).
# *   **Finance Briefings:** Daily Executive Briefs, Xelvia Global.
#
# **Potential Impact:**
#
# The AI/ML trends indicate a future of increased automation, enhanced efficiency, and novel problem-solving capabilities across industries. Agentic AI will transform how work is done, specialized models will drive targeted innovation, and generative AI will unlock new frontiers in scientific and creative endeavors. However, challenges related to data infrastructure, ethical considerations, and cybersecurity will need to be addressed for widespread and responsible adoption.
# AggregatorAgent > ## Executive Summary: Intersecting Trends in Technology, Health, and Finance
#
# The latest executive briefings reveal a powerful synergy driven by **AI and Machine Learning**, poised to reshape key industries. Generative AI is rapidly expanding beyond content creation into complex applications like drug discovery and materials science, while agentic AI promises significant workflow automation. This expansion is supported by a shift towards **specialized AI models** that offer greater accuracy and cost-effectiveness for specific enterprise needs, and is fueling demand for **application-specific semiconductors**.
#
# In **healthcare**, AI is enabling earlier detection of critical conditions, and new therapeutic advancements like teplizumab and RSV vaccines offer improved patient outcomes. However, rising healthcare costs due to chronic conditions, an aging population, and reliance on advanced treatments remain a challenge, prompting a growing emphasis on **preventive care and lifestyle interventions**.
#
# **Finance** is experiencing a similar AI-driven transformation, with enhanced risk assessment, fraud detection, and personalized services. Finance leaders are increasingly leveraging AI and cloud technologies for strategic growth. Simultaneously, trends like **Central Bank Digital Currencies (CBDCs)** and **private credit growth** indicate evolving financial landscapes.
#
# The overarching takeaway is that AI is no longer a nascent technology but an integral force driving efficiency, innovation, and strategic decision-making across all three sectors, while new health interventions and evolving financial instruments point towards a future of more personalized and potentially cost-effective solutions.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %% [markdown]
# To let an agent call this Python function, we wrap it in a `FunctionTool`. Then, we create a `RefinerAgent` that has this tool.
#
# 👉 **Notice its instructions:** this agent is the "brain" of the loop. It reads the `{critique}` from the `CriticAgent` and decides whether to (1) call the `exit_loop` tool or (2) rewrite the story.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %% [markdown]
# Then we bring the agents together under a loop agent, which is itself nested inside of a sequential agent.
#
# This design ensures that the system first produces an initial story draft, then the refinement loop runs up to the specified number of `max_iterations`:

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %% [markdown]
# Let's run the agent and give it a topic to write a short story about:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias, keeper of the Black Rock light, polished the lens for the hundredth time. The sea gnawed at the island, a relentless hunger. Tonight, a storm brewed, the air thick with salt and unease. As he secured the shutters, a glint caught his eye near the tide line. A small, leather-bound tube, miraculously unbroken. Inside, not parchment, but a strange, leathery substance. When he unfurled it, intricate lines pulsed with a soft, emerald light. It wasn't any map he'd ever seen. The symbols were alien, the geography utterly foreign, yet a single, bright point shimmered at its center, beckoning. The storm howled, but Elias felt a different kind of pull, one from beyond the familiar horizon.
# CriticAgent > The story introduces an intriguing premise with Elias and his discovery. However, to enhance the narrative, consider the following:
#
# *   **Character Development:** Elias is currently defined by his duty and his reaction to the map. Explore his motivations and inner thoughts further. What does he yearn for, if anything, that this map might fulfill? Does he have a history that makes this discovery particularly significant? Adding a brief glimpse into his personal life or past could make his decision to follow the map more compelling.
# *   **Pacing and Foreshadowing:** While the storm builds atmosphere, consider if there are subtle ways to foreshadow the map's existence or its unusual nature *before* Elias finds it. Perhaps a strange dream, an unusual tide pattern, or a fleeting anomaly he’s dismissed in the past. This could make the discovery feel less sudden and more integrated into the story's world.
# *   **Sensory Details and Description:** The "strange, leathery substance" and "intricate lines pulsed with a soft, emerald light" are good starting points. Expand on the sensory experience of the map. What does it feel like beyond "leathery"? Does it have a scent? How does the light interact with Elias's surroundings? More vivid descriptions could immerse the reader further into the mystery.
# RefinerAgent > Elias, keeper of the Black Rock light, polished the lens for the hundredth time, the rhythmic sweep of his cloth a familiar comfort against the gnawing hunger of the sea. He’d been here twenty years, a self-imposed exile after a life at sea that had promised adventure but delivered only brine-soaked regrets and the ghost of a lost love. Tonight, the air was a heavy, salt-laden shroud, and the storm that brewed felt more like a premonition than mere weather. He’d always felt a strange kinship with the sea’s turbulent moods, a quiet understanding born from countless solitary nights.
#
# As he secured the iron shutters against the encroaching tempest, a glint near the tide line snagged his attention. It was a small, leather-bound tube, impossibly intact against the waves’ assault. His weathered fingers, accustomed to the coarse ropes and cold metal of the lighthouse, fumbled with the clasp. Inside, not the expected parchment, but a material that felt strangely alive – supple, yet ancient, with a faint, earthy scent like a forest after rain.
#
# When he unfurled it, intricate lines, etched in a phosphorescent ink, pulsed with a soft, emerald light. It wasn't a map of any coast he knew; the symbols were alien, swirling like captured nebulae, and the geography depicted was utterly foreign, a landscape of jagged peaks and impossible, swirling seas. Yet, a single, bright point shimmered at its center, a beacon that seemed to resonate with a deep, unspoken yearning within him. For years, he’d stared at the horizon, a prisoner of his duty and his past, yearning for a horizon that held more than just the endless sea.
#
# The storm howled, a furious symphony that rattled the lighthouse tower, but Elias felt a different kind of pull, a silent, insistent call from beyond the familiar, and for the first time in two decades, the lonely light of Black Rock felt like a cage, not a sanctuary. The emerald light of the map seemed to warm his skin, and in its glow, he saw not just a map, but a promise – a chance to trade the predictable rhythm of the waves for the intoxicating unknown.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
